# %% [markdown]
# # 词嵌入模型与语义投影
# 参考文献：Grand, G., Blank, I.A., Pereira, F. and Fedorenko, E., 2022. Semantic projection recovers rich human knowledge of multiple object features from word embeddings. Nature Human Behaviour, pp.1-13.
#
# 参考教程：https://mp.weixin.qq.com/s/jsHXpYhNJCZ6VDse9Xwb_Q

# %%
'''
#首先安装需要的包
# !pip3 install whatlies==0.7.0
# !pip3 install matplotlib_inline
# !pip3 install gensim==4.2.0

'''
# Out:
# Collecting whatlies==0.7.0
#   Downloading whatlies-0.7.0-py2.py3-none-any.whl (84 kB)
#      -------------------------------------- 84.6/84.6 kB 432.6 kB/s eta 0:00:00
# Collecting gensim~=3.8.3
#   Downloading gensim-3.8.3-cp38-cp38-win_amd64.whl (24.2 MB)
#      --------------------------------------- 24.2/24.2 MB 10.9 MB/s eta 0:00:00
# Collecting bpemb>=0.3.0
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in d:\anaconda\lib\site-packages (from whatlies==0.7.0) (1.1.3)
# Collecting altair>=4.2.0
#   Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#      ------------------------------------- 813.6/813.6 kB 17.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.5.0 in d:\anaconda\lib\site-packages (from whatlies==0.7.0) (3.5.2)
# Requirement already satisfied: jsonschema>=3.0 in d:\anaconda\lib\site-packages (from altair>=4.2.0->whatlies==0.7.0) (4.16.0)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from altair>=4.2.0->whatlies==0.7.0) (1.21.5)
# Requirement already satisfied: toolz in d:\anaconda\lib\site-packages (from altair>=4.2.0->whatlies==0.7.0) (0.11.2)
# Requirement already satisfied: pandas>=0.18 in d:\anaconda\lib\site-packages (from altair>=4.2.0->whatlies==0.7.0) (1.4.4)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from altair>=4.2.0->whatlies==0.7.0) (2.11.3)
# Requirement already satisfied: entrypoints in d:\anaconda\lib\site-packages (from altair>=4.2.0->whatlies==0.7.0) (0.4)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from bpemb>=0.3.0->whatlies==0.7.0) (2.28.1)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from bpemb>=0.3.0->whatlies==0.7.0) (4.64.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-win_amd64.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 35.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.18.1 in d:\anaconda\lib\site-packages (from gensim~=3.8.3->whatlies==0.7.0) (1.10.0)
# Collecting Cython==0.29.14
#   Downloading Cython-0.29.14-cp38-cp38-win_amd64.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in d:\anaconda\lib\site-packages (from gensim~=3.8.3->whatlies==0.7.0) (6.3.0)
# Requirement already satisfied: six>=1.5.0 in d:\anaconda\lib\site-packages (from gensim~=3.8.3->whatlies==0.7.0) (1.16.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.5.0->whatlies==0.7.0) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.5.0->whatlies==0.7.0) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.5.0->whatlies==0.7.0) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib>=3.5.0->whatlies==0.7.0) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib>=3.5.0->whatlies==0.7.0) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib>=3.5.0->whatlies==0.7.0) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib>=3.5.0->whatlies==0.7.0) (9.2.0)
# Requirement already satisfied: joblib>=1.0.0 in d:\anaconda\lib\site-packages (from scikit-learn>=1.0.0->whatlies==0.7.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn>=1.0.0->whatlies==0.7.0) (2.2.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in d:\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->whatlies==0.7.0) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->whatlies==0.7.0) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in d:\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->whatlies==0.7.0) (5.2.0)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda\lib\site-packages (from jsonschema>=3.0->altair>=4.2.0->whatlies==0.7.0) (21.4.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas>=0.18->altair>=4.2.0->whatlies==0.7.0) (2022.1)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from jinja2->altair>=4.2.0->whatlies==0.7.0) (2.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->bpemb>=0.3.0->whatlies==0.7.0) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests->bpemb>=0.3.0->whatlies==0.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests->bpemb>=0.3.0->whatlies==0.7.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->bpemb>=0.3.0->whatlies==0.7.0) (2022.9.14)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm->bpemb>=0.3.0->whatlies==0.7.0) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in d:\anaconda\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair>=4.2.0->whatlies==0.7.0) (3.8.0)
# Installing collected packages: sentencepiece, Cython, gensim, bpemb, altair, whatlies
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.32
#     Uninstalling Cython-0.29.32:
#       Successfully uninstalled Cython-0.29.32
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.0
#     Uninstalling gensim-4.3.0:
#       Successfully uninstalled gensim-4.3.0
# Successfully installed Cython-0.29.14 altair-4.2.2 bpemb-0.3.4 gensim-3.8.3 sentencepiece-0.1.97 whatlies-0.7.0
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# Requirement already satisfied: matplotlib_inline in d:\anaconda\lib\site-packages (0.1.6)
# Requirement already satisfied: traitlets in d:\anaconda\lib\site-packages (from matplotlib_inline) (5.4.0)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# Collecting gensim==4.2.0
#   Downloading gensim-4.2.0-cp38-cp38-win_amd64.whl (24.0 MB)
#      --------------------------------------- 24.0/24.0 MB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in d:\anaconda\lib\site-packages (from gensim==4.2.0) (6.3.0)
# Requirement already satisfied: scipy>=0.18.1 in d:\anaconda\lib\site-packages (from gensim==4.2.0) (1.10.0)
# Requirement already satisfied: numpy>=1.17.0 in d:\anaconda\lib\site-packages (from gensim==4.2.0) (1.21.5)
# Collecting Cython==0.29.28
#   Downloading Cython-0.29.28-py2.py3-none-any.whl (983 kB)
#      ------------------------------------- 983.8/983.8 kB 31.4 MB/s eta 0:00:00
# Installing collected packages: Cython, gensim
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.14
#     Uninstalling Cython-0.29.14:
#       Successfully uninstalled Cython-0.29.14
#   Attempting uninstall: gensim
#     Found existing installation: gensim 3.8.3
#     Uninstalling gensim-3.8.3:
#       Successfully uninstalled gensim-3.8.3
# Successfully installed Cython-0.29.28 gensim-4.2.0
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
#     WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# whatlies 0.7.0 requires gensim~=3.8.3, but you have gensim 4.2.0 which is incompatible.
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -yproj (d:\anaconda\lib\site-packages)

# %% [markdown]
# ## 下载词向量资源
# 中文词向量资源 https://github.com/Embedding/Chinese-Word-Vectors
#
# Shen Li, Zhe Zhao, Renfen Hu, Wensi Li, Tao Liu, Xiaoyong Du, Analogical Reasoning on Chinese Morphological and Semantic Relations, ACL 2018.
#
# 此处使用预训练的人民日报词向量做测试

# %%
from gensim.models.keyedvectors import KeyedVectors

# 人民日报 sgns.renmin.word.bz2 为例  
#"H:\课程\DATA\sgns.renmin.word.bz2"
pdaily_wv = KeyedVectors.load_word2vec_format('H:/课程/DATA/sgns.renmin.word.bz2', 
                                             binary=False, 
                                             unicode_errors='ignore')
# Out:
# D:\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
#查看词汇量
len(pdaily_wv)
# Out:
# 355987

# %%
#提取某个词的向量
pdaily_wv['人民']
# Out:
# array([ 1.64313e-01, -4.31710e-02,  1.67749e-01,  5.03090e-02,
#        -2.48748e-01,  9.48800e-03,  2.11642e-01,  4.59560e-02,
#         1.14928e-01,  2.54482e-01,  1.73634e-01,  9.07000e-02,
#        -2.76401e-01,  2.69877e-01,  3.87000e-02,  1.46361e-01,
#        -2.11393e-01,  4.17446e-01,  4.66310e-02, -2.79912e-01,
#         1.35812e-01,  9.45610e-02,  3.14769e-01, -1.23438e-01,
#        -4.49589e-01, -6.08670e-02, -7.41950e-02, -2.51548e-01,
#         1.28148e-01, -5.59700e-02,  5.23940e-02,  4.09700e-02,
#        -2.51117e-01,  6.49830e-02, -4.90290e-01, -1.92180e-01,
#        -3.83229e-01,  4.24360e-02, -7.55521e-01,  4.00192e-01,
#         3.52161e-01,  2.90011e-01,  7.84775e-01,  9.74940e-02,
#         5.28462e-01,  5.22956e-01, -1.09933e-01, -2.15697e-01,
#         3.33763e-01, -1.56300e-02, -1.29792e-01,  9.30630e-02,
#        -1.17581e-01,  8.86400e-02, -6.26970e-02, -1.42509e-01,
#         3.63720e-02, -1.86804e-01, -6.62520e-02,  1.03657e-01,
#        -3.28504e-01, -1.38237e-01,  1.63520e-01,  1.60156e-01,
#         4.23697e-01,  3.53062e-01, -8.49780e-02,  1.01320e-01,
#        -2.45010e-02, -3.49258e-01, -1.35951e-01,  3.99218e-01,
#         2.21095e-01, -4.12000e-02,  8.24890e-02,  4.47643e-01,
#        -2.69320e-01,  2.48477e-01, -2.68698e-01, -1.94129e-01,
#        -1.69003e-01, -4.12216e-01,  1.89353e-01, -1.16112e-01,
#         2.77290e-01, -1.31202e-01, -7.14240e-02,  9.23740e-02,
#         5.21280e-02,  1.55424e-01,  6.98070e-02, -1.77347e-01,
#         4.95500e-03, -1.15310e-02, -7.94440e-02, -2.30219e-01,
#        -1.97293e-01,  1.47200e-01,  2.84886e-01,  2.03256e-01,
#        -2.57960e-01,  1.23163e-01, -2.97025e-01,  3.33210e-02,
#        -1.89003e-01,  3.65000e-04,  1.34485e-01, -6.24234e-01,
#         5.98070e-02, -5.23988e-01,  4.82978e-01,  1.29052e-01,
#        -7.28538e-01, -1.84650e-02, -9.23750e-02,  1.93532e-01,
#         6.43080e-02,  4.24872e-01, -1.14620e-01,  2.65025e-01,
#        -2.39051e-01,  1.21295e-01,  4.68860e-02, -7.02780e-02,
#         2.22258e-01,  2.65833e-01, -1.06888e-01,  1.74824e-01,
#         3.16455e-01,  2.48429e-01,  1.66924e-01,  4.31004e-01,
#        -2.49733e-01,  4.54174e-01,  1.79763e-01,  1.41870e-01,
#        -5.82202e-01,  6.70959e-01,  3.03160e-01, -1.53225e-01,
#         3.13600e-02, -2.02783e-01, -5.02920e-02,  6.28326e-01,
#         1.49766e-01,  3.47804e-01,  1.08963e-01, -2.56477e-01,
#        -3.94767e-01,  1.95424e-01,  8.17370e-02,  3.80762e-01,
#         2.75890e-01, -9.07170e-02,  1.38636e-01, -1.39938e-01,
#         1.28464e-01,  2.09621e-01, -1.26534e-01,  8.03500e-03,
#         1.66371e-01, -3.34678e-01,  8.34720e-02, -3.18715e-01,
#         1.46361e-01,  5.37700e-02, -2.56725e-01,  2.03111e-01,
#         5.76312e-01, -1.10825e-01,  8.97680e-02, -2.98246e-01,
#         2.67975e-01,  7.26726e-01, -6.55060e-02, -2.59833e-01,
#        -3.77070e-02,  2.01390e-01,  6.50270e-02, -5.25270e-02,
#        -1.05303e-01,  2.24496e-01, -2.07039e-01, -4.49900e-03,
#         5.08228e-01, -2.07171e-01,  1.94050e-02, -2.63604e-01,
#         3.79590e-01, -3.12450e-02,  1.05909e-01, -9.98240e-02,
#         6.77040e-02,  1.13551e-01, -5.54720e-02, -2.74611e-01,
#         1.80654e-01, -1.20830e-01,  2.97790e-01,  1.56963e-01,
#         3.19087e-01, -1.51980e-02, -6.36595e-01,  2.02711e-01,
#        -9.53120e-02, -4.86918e-01,  2.65685e-01,  1.15548e-01,
#         2.52972e-01,  3.04800e-03,  6.56405e-01,  2.51172e-01,
#         6.50120e-02, -2.59525e-01, -1.84501e-01,  4.19230e-02,
#        -5.88180e-02,  1.60260e-02,  4.66000e-04,  3.16620e-01,
#         6.30052e-01,  5.53865e-01,  1.80737e-01,  3.36752e-01,
#         4.31318e-01,  4.39836e-01, -4.87220e-02, -2.19482e-01,
#         4.45054e-01, -3.10473e-01,  4.07410e-02,  1.27407e-01,
#         3.32042e-01, -2.21259e-01, -4.12658e-01,  3.44560e-02,
#        -2.17895e-01, -1.80321e-01, -3.01968e-01,  1.73942e-01,
#        -5.26525e-01, -3.53560e-02, -7.88930e-02, -3.14101e-01,
#        -3.44132e-01, -2.42361e-01,  8.28700e-02,  2.35870e-02,
#        -1.28127e-01, -1.29120e-01,  2.43100e-02, -1.74924e-01,
#         3.31162e-01, -1.11488e-01, -6.43280e-02, -2.35020e-01,
#         6.44250e-02, -2.35608e-01,  1.49772e-01, -3.30627e-01,
#        -9.64700e-02, -3.96695e-01, -8.01570e-02, -1.60536e-01,
#        -2.07485e-01, -1.97253e-01,  1.22710e-02, -3.46890e-02,
#        -2.84346e-01,  4.95240e-02, -8.06310e-02, -1.83269e-01,
#        -7.67860e-02, -4.36828e-01,  3.25783e-01,  4.41630e-02,
#        -4.12081e-01,  4.15344e-01,  8.65660e-02,  2.27856e-01,
#         1.44215e-01,  3.56024e-01,  7.72250e-02,  3.63450e-02,
#        -1.63253e-01,  9.56770e-02,  1.79874e-01,  1.91024e-01,
#        -6.26632e-01,  2.82249e-01, -1.88344e-01, -1.56320e-02,
#        -1.24853e-01, -1.13451e-01, -4.41710e-02, -1.10472e-01,
#        -2.26130e-01, -2.33013e-01, -4.19536e-01, -3.89400e-01],
#       dtype=float32)

# %%
#查看词的维度
len(pdaily_wv['人民'])
# Out:
# 300

# %%
#最相似的词
pdaily_wv.most_similar("可爱", topn=10)
# Out:
# [('娇憨', 0.6214803457260132),
#  ('逗人喜爱', 0.5989802479743958),
#  ('无邪', 0.5909478664398193),
#  ('健康活泼', 0.5882358551025391),
#  ('乖巧', 0.5867952108383179),
#  ('活泼可爱', 0.5852850675582886),
#  ('那群', 0.5847833752632141),
#  ('驯良', 0.5839908123016357),
#  ('丑得', 0.581652820110321),
#  ('憨态', 0.5774826407432556)]

# %% [markdown]
# ## 向量投影

# %%
import matplotlib.pyplot as plt
import matplotlib
import platform
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('png', 'svg')
# 以下代码从全局设置字体为SimHei（黑体），解决显示中文问题【Windows】
# 设置font.sans-serif 或 font.family 均可
plt.rcParams['font.sans-serif'] = ['SimHei']
# plt.rcParams['font.family']=['SimHei']
# 解决中文字体下坐标轴负数的负号显示问题
plt.rcParams['axes.unicode_minus'] = False

# %%
# 获取需要绘制的单词列表
words = ['海豚', '象', '狮子', '老虎', '蓝鲸', '狗', '猫', '鼠', '蜜蜂']

# 获取词向量，并转换为 NumPy 数组
vectors = np.array([pdaily_wv[word] for word in words])

# 把大-小（尺寸）作为特征子空间
x_axis = pdaily_wv[['大']].mean(axis=0) - pdaily_wv[['小']].mean(axis=0)

# 把危险-安全（危险性）作为特征子空间
y_axis = pdaily_wv[['危险', '威胁', '可怕']].mean(axis=0) - pdaily_wv[['安全', '无害', '可爱']].mean(axis=0)

# 计算每个词向量在新坐标系中的投影
x_coords = np.dot(vectors, x_axis)
y_coords = np.dot(vectors, y_axis)

# 绘制图形
fig, ax = plt.subplots()
ax.scatter(x_coords, y_coords)

for i, word in enumerate(words):
    ax.annotate(word, (x_coords[i], y_coords[i]))

# 绘制 x 轴和 y 轴的十字线
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

plt.xlim(-2, 2)
plt.ylim(-2, 2)

plt.xlabel('尺寸')
plt.ylabel('安全性')

plt.title('动物的尺寸与安全性')
#plt.show()

#保存
plt.savefig(fname="动物的尺寸与安全性.png", dpi=300)

# %%
# 获取需要绘制的单词列表
words = ['海豚', '象', '狮子', '老虎', '蓝鲸', '狗', '猫', '鼠', '蜜蜂']

# 获取词向量，并转换为 NumPy 数组
vectors = np.array([pdaily_wv[word] for word in words])

# 把大-小（尺寸）作为特征子空间
x_axis = pdaily_wv[['巨大', '极大', '大']].mean(axis=0) - pdaily_wv[['很小', '太小', '小']].mean(axis=0)

# 把危险-安全（危险性）作为特征子空间
y_axis = pdaily_wv[['危险', '威胁', '可怕']].mean(axis=0) - pdaily_wv[['安全', '无害', '可爱']].mean(axis=0)

# 计算每个词向量在新坐标系中的投影
x_coords = np.dot(vectors, x_axis)
y_coords = np.dot(vectors, y_axis)

# 绘制图形
fig, ax = plt.subplots()
ax.scatter(x_coords, y_coords)

for i, word in enumerate(words):
    ax.annotate(word, (x_coords[i], y_coords[i]))

# 绘制 x 轴和 y 轴的十字线
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

plt.xlim(-2, 2)
plt.ylim(-2, 2)

plt.xlabel('尺寸')
plt.ylabel('安全性')

plt.title('动物的尺寸与安全性')
#plt.show()

#保存
plt.savefig(fname="动物的尺寸与安全性.png", dpi=300)

# %%
words = ['海豚', '象', '狮子', '老虎', '蓝鲸', '狗', '猫', '鼠', '蜜蜂']
dis_from_vec = []
for i in words:
    dis1 = pdaily_wv.distance(i,'巨大')
    dis2 = pdaily_wv.distance(i,'极大')
    dis3 = pdaily_wv.distance(i,'大')
    dis = (dis1+dis2+dis3)/3
    dis_from_vec.append(dis)

# %%
import pandas as pd
size_dis = pd.DataFrame(data = list(zip(words, dis_from_vec)),columns =['animal','distance'])

# %%
size_dis.sort_values('distance')
# Out:
#   animal  distance
# 1      象  0.825249
# 4     蓝鲸  0.837640
# 6      猫  0.851794
# 3     老虎  0.870167
# 2     狮子  0.870390
# 0     海豚  0.879822
# 5      狗  0.882804
# 8     蜜蜂  0.898865
# 7      鼠  0.906508

# %% [markdown]
# 跟单独与某一极的词向量求距离相比，在特征维度上投影的结果更真实。

# %%
# 获取需要绘制的单词列表
words = ['美国', '中国', '日本', '英国', '印度', '韩国', '俄罗斯', '乌克兰', '巴基斯坦', '法国']

# 获取词向量，并转换为 NumPy 数组
vectors = np.array([pdaily_wv[word] for word in words])

# 把强大-弱小（国力）作为特征子空间
x_axis = pdaily_wv[['强大', '富有', '发达']].mean(axis=0) - pdaily_wv[['弱小', '贫穷', '落后']].mean(axis=0)

# 把危险-安全（危险性）作为特征子空间
y_axis = pdaily_wv[['危险', '威胁', '战争']].mean(axis=0) - pdaily_wv[['安全', '无害', '和平']].mean(axis=0)

# 计算每个词向量在新坐标系中的投影
x_coords = np.dot(vectors, x_axis)
y_coords = np.dot(vectors, y_axis)

# 绘制图形
fig, ax = plt.subplots()
ax.scatter(x_coords, y_coords)

for i, word in enumerate(words):
    ax.annotate(word, (x_coords[i], y_coords[i]))

# 绘制 x 轴和 y 轴的十字线
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

plt.xlim(-2, 2)
plt.ylim(-2, 2)

plt.xlabel('国力')
plt.ylabel('安全性')

plt.title('《人民日报》中国家的国力与安全性')
#plt.show()

#保存
plt.savefig(fname="《人民日报》中国家的国力与安全性.png", dpi=300)

# %%
#参照论文中的方法
# 获取需要绘制的单词列表
from sklearn.decomposition import PCA

words = ['海豚', '象', '狮子', '老虎', '蓝鲸', '狗', '猫', '鼠', '蜜蜂', '巨大', '极大', '大', '很小', '太小', '小']

# 获取词向量，并转换为 NumPy 数组
vectors = np.array([pdaily_wv[word] for word in words])

pca = PCA(n_components=3)   #降到3维
pca.fit(vectors)                  
new_vectors=pca.fit_transform(vectors)

# %%
new_vectors
# Out:
# array([[-1.3640988 ,  0.7155162 ,  1.8507148 ],
#        [ 0.15477127, -0.22500618,  1.3658524 ],
#        [-1.8734536 , -1.6792411 , -0.17757078],
#        [-1.7432069 , -1.2516356 , -1.3544899 ],
#        [-0.67184716,  0.0891082 ,  0.9518924 ],
#        [-1.6844541 ,  0.37536559, -0.9105619 ],
#        [-1.9639002 , -0.49276498, -0.8577417 ],
#        [-2.2922082 ,  0.10021254, -1.1198632 ],
#        [-1.3063357 ,  2.4249997 ,  2.0191023 ],
#        [ 2.4199717 , -1.6971979 ,  1.0926749 ],
#        [ 2.157927  , -2.1882188 ,  0.84450936],
#        [ 2.2644637 ,  0.15223841, -0.32406938],
#        [ 2.1311302 ,  1.0545695 , -0.93325377],
#        [ 2.1224847 ,  1.5175301 , -1.2620474 ],
#        [ 1.6487563 ,  1.1045245 , -1.1851484 ]], dtype=float32)

# %%
# 把大-小（尺寸）作为特征子空间
avg_size_big = new_vectors[9:12].mean(axis = 0)
avg_size_small = new_vectors[12:15].mean(axis = 0)

# %%
avg_size_big
# Out:
# array([ 2.2807875 , -1.2443928 ,  0.53770494], dtype=float32)

# %%
size_xs = [avg_size_big[0],avg_size_small[0]]
size_ys = [avg_size_big[1],avg_size_small[1]]
size_zs = [avg_size_big[2],avg_size_small[2]]

# %%
animal_xs = new_vectors[:9,0]
animal_ys = new_vectors[:9,1]
animal_zs = new_vectors[:9,2]
animal_label = words[:9]

# %%
#导入三维工具包mplot3d
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
#创建3d绘图区域
ax = plt.axes(projection='3d')
ax.plot(size_xs, size_ys, size_zs, label='size')
scatter = ax.scatter(animal_xs,animal_ys,animal_zs,c=range(9))
a,b=scatter.legend_elements()
b=['$\\mathdefault {海豚}$',
 '$\\mathdefault{象}$',
 '$\\mathdefault{狮子}$',
 '$\\mathdefault{老虎}$',
 '$\\mathdefault{蓝鲸}$',
 '$\\mathdefault{狗}$',
 '$\\mathdefault{猫}$',
 '$\\mathdefault{鼠}$',
 '$\\mathdefault{蜜蜂}$',]
legend1 = ax.legend(a,b, title="Classes")
ax.view_init(elev=45, azim=45)

# %% [markdown]
# ## 启发
# 道德基础理论中每一维度都是由两极构成，如“Care-Harm”，可以使用一个大规模的语料库将许多词向量投射到这一维度，并保存下这些词语的分数，后续需要对文本进行道德基础分析时可以调用上述结果，性能应该会优于单纯的词频统计。
