# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('H:/课程/毕业论文/active_User_per_30_days_processed.csv')

# %%
df.head()
# Out:
#    Unnamed: 0    Datetime             Tweet_id  \
# 0           0  2022-02-22  1496098801152512002
# 1           1  2022-02-22  1496099780912881665
# 2           2  2022-02-22  1496103001903501319
# 3           3  2022-02-22  1496107122718695424
# 4           4  2022-02-22  1496107229929476105
#
#                                        Tweet_content  Tweet_reply_count  \
# 0   putins war   ukraine russia crisis  ukraina  ...                  0
# 1  Proud moment for  indiaTwo young shining stars...                  0
# 2  Russia vs Ukraine War Update: Germany halts No...                  1
# 3   putins war :Interesting details on other terr...                  0
# 4    criminals in  russia,  iran, syria!are the w...                  0
#
#    Tweet_retweet_count  Tweet_like_count  Tweet_quote_count  \
# 0                    0                 1                  0
# 1                    0                 1                  0
# 2                    0                 1                  0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Datetime', 'Tweet_id', 'Tweet_content',
#        'Tweet_reply_count', 'Tweet_retweet_count', 'Tweet_like_count',
#        'Tweet_quote_count', 'Tweet_hashtags', 'Username', 'User_id',
#        'User_followers_count', 'User_friends_count', 'User_statuses_count',
#        'User_favourites_count', 'User_listed_count', 'User_media_count',
#        'HorA', 'care', 'fairness', 'loyalty', 'authority', 'purity',
#        'authority_cat', 'care_cat', 'fairness_cat', 'purity_cat',
#        'loyalty_cat', '30day_cut', 'Tweet_content_clean', 'url_num', 'at_num',
#        'emoji_num', 'User_infuluence_score'],
#       dtype='object')

# %%
df['Tweet_be_retweeted'] = df['Tweet_retweet_count'].apply(lambda x: 0+(x>0))
df['Tweet_be_retweeted_50'] = df['Tweet_retweet_count'].apply(lambda x: 0+(x>=50))
df['Tweet_be_retweeted_100'] = df['Tweet_retweet_count'].apply(lambda x: 0+(x>=100))
df['Tweet_be_retweeted_500'] = df['Tweet_retweet_count'].apply(lambda x: 0+(x>=500))
df['Tweet_be_retweeted_1000'] = df['Tweet_retweet_count'].apply(lambda x: 0+(x>=1000))
df['Tweet_be_retweeted_10000'] = df['Tweet_retweet_count'].apply(lambda x: 0+(x>=10000))

# %%
df[['Tweet_be_retweeted',
   'Tweet_be_retweeted_50', 'Tweet_be_retweeted_100',
   'Tweet_be_retweeted_500', 'Tweet_be_retweeted_1000',
   'Tweet_be_retweeted_10000']].describe()
# Out:
#        Tweet_be_retweeted  Tweet_be_retweeted_50  Tweet_be_retweeted_100  \
# count        2.730753e+06           2.730753e+06            2.730753e+06
# mean         3.318231e-01           1.948107e-02            1.163049e-02
# std          4.708679e-01           1.382084e-01            1.072158e-01
# min          0.000000e+00           0.000000e+00            0.000000e+00
# 25%          0.000000e+00           0.000000e+00            0.000000e+00
# 50%          0.000000e+00           0.000000e+00            0.000000e+00
# 75%          1.000000e+00           0.000000e+00            0.000000e+00
# max          1.000000e+00           1.000000e+00            1.000000e+00
#
#        Tweet_be_retweeted_500  Tweet_be_retweeted_1000  \
# count            2.730753e+06             2.730753e+06
# mean             2.368577e-03             9.338084e-04
# std              4.861037e-02             3.054401e-02
# min              0.000000e+00             0.000000e+00
# ...

# %%
df[['Tweet_be_retweeted',
   'Tweet_be_retweeted_50', 'Tweet_be_retweeted_100',
   'Tweet_be_retweeted_500', 'Tweet_be_retweeted_1000',
   'Tweet_be_retweeted_10000']].sum()
# Out:
# Tweet_be_retweeted          906127
# Tweet_be_retweeted_50        53198
# Tweet_be_retweeted_100       31760
# Tweet_be_retweeted_500        6468
# Tweet_be_retweeted_1000       2550
# Tweet_be_retweeted_10000        81
# dtype: int64

# %%
df[['User_followers_count','Tweet_retweet_count']].describe()
# Out:
#        User_followers_count  Tweet_retweet_count
# count          2.730753e+06         2.730753e+06
# mean           9.054230e+04         7.593914e+00
# std            8.405801e+05         1.575008e+02
# min            0.000000e+00         0.000000e+00
# 25%            3.580000e+02         0.000000e+00
# 50%            1.565000e+03         0.000000e+00
# 75%            7.329000e+03         1.000000e+00
# max            1.770676e+07         1.005870e+05

# %%
ddf = df[df['30day_cut']>=0].pivot_table(index=['User_id','30day_cut'], 
                                         values=['care','fairness','purity','authority','loyalty','HorA','emoji_num','url_num',
                                                 'User_infuluence_score','User_followers_count','Tweet_retweet_count',
                                                 'Tweet_be_retweeted','Tweet_id','Tweet_be_retweeted_50', 
                                                 'Tweet_be_retweeted_100', 'Tweet_be_retweeted_500', 
                                                 'Tweet_be_retweeted_1000', 'Tweet_be_retweeted_10000'], 
                                         aggfunc={'care':np.mean,
                                                  'fairness':np.mean,
                                                  'purity':np.mean,
                                                  'authority':np.mean,
                                                  'loyalty':np.mean,
                                                  'HorA':np.mean,
                                                  'emoji_num':np.mean,
                                                  'url_num':np.mean,
                                                  'User_infuluence_score':np.mean,
                                                  'User_followers_count':np.mean,
                                                  'Tweet_retweet_count':np.mean,
                                                  'Tweet_be_retweeted':np.mean,
                                                  'Tweet_be_retweeted_50':np.mean,
                                                  'Tweet_be_retweeted_100':np.mean,
                                                  'Tweet_be_retweeted_500':np.mean,
                                                  'Tweet_be_retweeted_1000':np.mean,
                                                  'Tweet_be_retweeted_10000':np.mean,
                                                  'Tweet_id':len})

# %%
ddf.describe()
# Out:
#                HorA  Tweet_be_retweeted  Tweet_be_retweeted_100  \
# count  94472.000000        94472.000000            94472.000000
# mean       0.054366            0.322008                0.007633
# std        0.136935            0.355062                0.064546
# min        0.000000            0.000000                0.000000
# 25%        0.000000            0.000000                0.000000
# 50%        0.000000            0.181818                0.000000
# 75%        0.038462            0.542857                0.000000
# max        1.000000            1.000000                1.000000
#
#        Tweet_be_retweeted_1000  Tweet_be_retweeted_10000  \
# count             94472.000000              94472.000000
# mean                  0.000514                  0.000024
# std                   0.012790                  0.001987
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# ...

# %%
ddf[['User_followers_count','Tweet_be_retweeted']].describe()
# Out:
#        User_followers_count  Tweet_be_retweeted
# count          9.447200e+04        94472.000000
# mean           2.713646e+04            0.322008
# std            3.493593e+05            0.355062
# min            0.000000e+00            0.000000
# 25%            2.943943e+02            0.000000
# 50%            1.153768e+03            0.181818
# 75%            4.281260e+03            0.542857
# max            1.767574e+07            1.000000

# %%
'''
#清除异常值
def drop_outliers(df,colname):
    iqr = 1.5*(np.percentile(df[colname],75)-np.percentile(df[colname],25))
    df.drop(df[df[colname]>(iqr+np.percentile(df[colname],75))].index, inplace=True)
    df.drop(df[df[colname]<(np.percentile(df[colname],25)-iqr)].index, inplace=True)
    '''
# Out:
# '\n#清除异常值\ndef drop_outliers(df,colname):\n    iqr = 1.5*(np.percentile(df[colname],75)-np.percentile(df[colname],25))\n    df.drop(df[df[colname]>(iqr+np.percentile(df[colname],75))].index, inplace=True)\n    df.drop(df[df[colname]<(np.percentile(df[colname],25)-iqr)].index, inplace=True)\n    '

# %%
ddf['User_followers_count_log'] = ddf['User_followers_count'].apply(lambda x:np.log(x+1))

# %%
from linearmodels import PanelOLS
reg_fe = PanelOLS.from_formula('Tweet_be_retweeted ~ care*HorA + fairness*HorA + authority*HorA + purity*HorA + loyalty*HorA + User_followers_count_log*HorA + EntityEffects+TimeEffects', data=ddf)
results_fe = reg_fe.fit()
print(results_fe)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:     Tweet_be_retweeted   R-squared:                        0.0008
# Estimator:                   PanelOLS   R-squared (Between):             -2.6627
# No. Observations:               94472   R-squared (Within):               0.0006
# Date:                Sun, May 21 2023   R-squared (Overall):             -2.2855
# Time:                        10:46:59   Log-likelihood                 2.782e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.7662
# Entities:                       13496   P-value                           0.0000
# Avg Obs:                       7.0000   Distribution:                F(13,80957)
# Min Obs:                       7.0000
# Max Obs:                       7.0000   F-statistic (robust):             4.7662
#                                         P-value                           0.0000
# ...

# %%
#将发帖量加入模型
reg_fe = PanelOLS.from_formula('Tweet_be_retweeted ~ care*HorA + fairness*HorA + authority*HorA + purity*HorA + loyalty*HorA + User_followers_count_log*HorA + Tweet_id*HorA + EntityEffects+TimeEffects', data=ddf)
results_fe = reg_fe.fit()
print(results_fe)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:     Tweet_be_retweeted   R-squared:                        0.0009
# Estimator:                   PanelOLS   R-squared (Between):             -2.6686
# No. Observations:               94472   R-squared (Within):               0.0006
# Date:                Sun, May 21 2023   R-squared (Overall):             -2.2906
# Time:                        10:47:01   Log-likelihood                 2.783e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      4.6066
# Entities:                       13496   P-value                           0.0000
# Avg Obs:                       7.0000   Distribution:                F(15,80955)
# Min Obs:                       7.0000
# Max Obs:                       7.0000   F-statistic (robust):             4.6066
#                                         P-value                           0.0000
# ...

# %%
#将因变量换成大于k的转发率
#将发帖量加入模型
reg_fe = PanelOLS.from_formula('Tweet_be_retweeted_50 ~ care*HorA + fairness*HorA + authority*HorA + purity*HorA + loyalty*HorA + User_followers_count_log*HorA + Tweet_id*HorA + EntityEffects+TimeEffects', data=ddf)
results_fe = reg_fe.fit()
print(results_fe)
# Out:
#                             PanelOLS Estimation Summary
# ...
# Dep. Variable:     Tweet_be_retweeted_50   R-squared:                        0.0008
# Estimator:                      PanelOLS   R-squared (Between):             -1.0740
# No. Observations:                  94472   R-squared (Within):               0.0006
# Date:                   Sun, May 21 2023   R-squared (Overall):             -0.8455
# Time:                           10:47:02   Log-likelihood                  1.64e+05
# Cov. Estimator:               Unadjusted
#                                            F-statistic:                      4.3153
# Entities:                          13496   P-value                           0.0000
# Avg Obs:                          7.0000   Distribution:                F(15,80955)
# Min Obs:                          7.0000
# Max Obs:                          7.0000   F-statistic (robust):             4.3153
# ...

# %%
#将因变量换成大于k的转发率
#将发帖量加入模型
reg_fe = PanelOLS.from_formula('Tweet_be_retweeted_100 ~ care*HorA + fairness*HorA + authority*HorA + purity*HorA + loyalty*HorA + User_followers_count_log*HorA + Tweet_id*HorA + EntityEffects+TimeEffects', data=ddf)
results_fe = reg_fe.fit()
print(results_fe)
# Out:
#                             PanelOLS Estimation Summary
# ...
# Dep. Variable:     Tweet_be_retweeted_100   R-squared:                        0.0006
# Estimator:                       PanelOLS   R-squared (Between):             -0.9820
# No. Observations:                   94472   R-squared (Within):               0.0005
# Date:                    Sun, May 21 2023   R-squared (Overall):             -0.7262
# Time:                            10:47:04   Log-likelihood                 1.878e+05
# Cov. Estimator:                Unadjusted
#                                             F-statistic:                      3.4895
# Entities:                           13496   P-value                           0.0000
# Avg Obs:                           7.0000   Distribution:                F(15,80955)
# Min Obs:                           7.0000
# Max Obs:                           7.0000   F-statistic (robust):             3.4895
# ...

# %%
#将因变量换成大于k的转发率
#将发帖量加入模型
reg_fe = PanelOLS.from_formula('Tweet_be_retweeted_500 ~ care*HorA + fairness*HorA + authority*HorA + purity*HorA + loyalty*HorA + User_followers_count_log*HorA + Tweet_id*HorA + EntityEffects+TimeEffects', data=ddf)
results_fe = reg_fe.fit()
print(results_fe)
# Out:
#                             PanelOLS Estimation Summary
# ...
# Dep. Variable:     Tweet_be_retweeted_500   R-squared:                        0.0001
# Estimator:                       PanelOLS   R-squared (Between):             -0.6396
# No. Observations:                   94472   R-squared (Within):            8.376e-05
# Date:                    Sun, May 21 2023   R-squared (Overall):             -0.3801
# Time:                            10:47:05   Log-likelihood                  2.73e+05
# Cov. Estimator:                Unadjusted
#                                             F-statistic:                      0.5610
# Entities:                           13496   P-value                           0.9061
# Avg Obs:                           7.0000   Distribution:                F(15,80955)
# Min Obs:                           7.0000
# Max Obs:                           7.0000   F-statistic (robust):             0.5610
# ...

# %%
#将因变量换成大于k的转发率
#将发帖量加入模型
reg_fe = PanelOLS.from_formula('Tweet_be_retweeted_1000 ~ care*HorA + fairness*HorA + authority*HorA + purity*HorA + loyalty*HorA + User_followers_count_log*HorA + Tweet_id*HorA + EntityEffects+TimeEffects', data=ddf)
results_fe = reg_fe.fit()
print(results_fe)
# Out:
#                              PanelOLS Estimation Summary
# ...
# Dep. Variable:     Tweet_be_retweeted_1000   R-squared:                        0.0001
# Estimator:                        PanelOLS   R-squared (Between):             -0.6773
# No. Observations:                    94472   R-squared (Within):               0.0001
# Date:                     Sun, May 21 2023   R-squared (Overall):             -0.3141
# Time:                             10:47:07   Log-likelihood                 3.072e+05
# Cov. Estimator:                 Unadjusted
#                                              F-statistic:                      0.7867
# Entities:                            13496   P-value                           0.6941
# Avg Obs:                            7.0000   Distribution:                F(15,80955)
# Min Obs:                            7.0000
# Max Obs:                            7.0000   F-statistic (robust):             0.7867
# ...

# %%
#将因变量换成大于k的转发率
#将发帖量加入模型
reg_fe = PanelOLS.from_formula('Tweet_be_retweeted_10000 ~ care*HorA + fairness*HorA + authority*HorA + purity*HorA + loyalty*HorA + User_followers_count_log*HorA + Tweet_id*HorA + EntityEffects+TimeEffects', data=ddf)
results_fe = reg_fe.fit()
print(results_fe)
# Out:
#                              PanelOLS Estimation Summary
# ...
# Dep. Variable:     Tweet_be_retweeted_10000   R-squared:                        0.0002
# Estimator:                         PanelOLS   R-squared (Between):             -1.0367
# No. Observations:                     94472   R-squared (Within):               0.0001
# Date:                      Sun, May 21 2023   R-squared (Overall):             -0.2382
# Time:                              10:47:09   Log-likelihood                  4.66e+05
# Cov. Estimator:                  Unadjusted
#                                               F-statistic:                      0.8129
# Entities:                             13496   P-value                           0.6643
# Avg Obs:                             7.0000   Distribution:                F(15,80955)
# Min Obs:                             7.0000
# Max Obs:                             7.0000   F-statistic (robust):             0.8129
# ...

# %%
ddf['authority_lag']=ddf['authority'].shift(1)

# %%
ddf[['authority','authority_lag']].head()
# Out:
#                    authority  authority_lag
# User_id 30day_cut
# 1378    0           0.041622            NaN
#         1           0.025209       0.041622
#         2           0.035638       0.025209
#         3           0.092585       0.035638
#         4           0.056713       0.092585

# %%
ddf['care_lag']=ddf['care'].shift(1)
ddf['fairness_lag']=ddf['fairness'].shift(1)
ddf['purity_lag']=ddf['purity'].shift(1)
ddf['loyalty_lag']=ddf['loyalty'].shift(1)
ddf['HorA_lag']=ddf['HorA'].shift(1)
ddf['Tweet_id_lag']=ddf['Tweet_id'].shift(1)

# %%
#dropna
ddf1 = ddf.dropna()

# %%
#将发帖量加入模型
#换成滞后项
reg_fe = PanelOLS.from_formula('Tweet_be_retweeted ~ care_lag*HorA_lag + fairness_lag*HorA_lag + authority_lag*HorA_lag + purity_lag*HorA_lag + loyalty_lag*HorA_lag + User_followers_count_log*HorA_lag + Tweet_id_lag*HorA_lag + EntityEffects+TimeEffects', data=ddf1)
results_fe = reg_fe.fit()
print(results_fe)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:     Tweet_be_retweeted   R-squared:                        0.0005
# Estimator:                   PanelOLS   R-squared (Between):             -2.6507
# No. Observations:               94471   R-squared (Within):               0.0003
# Date:                Sun, May 21 2023   R-squared (Overall):             -2.2752
# Time:                        10:47:11   Log-likelihood                 2.781e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.7479
# Entities:                       13496   P-value                           0.0003
# Avg Obs:                       6.9999   Distribution:                F(15,80954)
# Min Obs:                       6.0000
# Max Obs:                       7.0000   F-statistic (robust):             2.7479
#                                         P-value                           0.0003
# ...

# %%
#仇恨言论与道德叙事，零模型
reg_fe = PanelOLS.from_formula('HorA ~care + fairness + authority + purity + loyalty +EntityEffects +TimeEffects', data=ddf)
results_fe_0 = reg_fe.fit()
print(results_fe_0)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:                   HorA   R-squared:                        0.0051
# Estimator:                   PanelOLS   R-squared (Between):              0.0824
# No. Observations:               94472   R-squared (Within):               0.0051
# Date:                Sun, May 21 2023   R-squared (Overall):              0.0438
# Time:                        10:56:48   Log-likelihood                     8e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      82.325
# Entities:                       13496   P-value                           0.0000
# Avg Obs:                       7.0000   Distribution:                 F(5,80965)
# Min Obs:                       7.0000
# Max Obs:                       7.0000   F-statistic (robust):             82.325
#                                         P-value                           0.0000
# ...

# %%
#仇恨言论与道德叙事，控制变量a
reg_fe = PanelOLS.from_formula('HorA ~ care + fairness + authority + purity + loyalty + emoji_num + url_num +User_followers_count_log+EntityEffects +TimeEffects', data=ddf)
results_fe_1 = reg_fe.fit()
print(results_fe_1)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:                   HorA   R-squared:                        0.0073
# Estimator:                   PanelOLS   R-squared (Between):             -0.0886
# No. Observations:               94472   R-squared (Within):               0.0073
# Date:                Sun, May 21 2023   R-squared (Overall):             -0.0407
# Time:                        10:57:09   Log-likelihood                  8.01e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      74.072
# Entities:                       13496   P-value                           0.0000
# Avg Obs:                       7.0000   Distribution:                 F(8,80962)
# Min Obs:                       7.0000
# Max Obs:                       7.0000   F-statistic (robust):             74.072
#                                         P-value                           0.0000
# ...

# %%
#仇恨言论与道德叙事，控制发帖量
reg_fe = PanelOLS.from_formula('HorA ~ care + fairness + authority + purity + loyalty + emoji_num + url_num +User_followers_count_log+Tweet_id+EntityEffects +TimeEffects', data=ddf)
results_fe_2 = reg_fe.fit()
print(results_fe_2)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:                   HorA   R-squared:                        0.0073
# Estimator:                   PanelOLS   R-squared (Between):             -0.0605
# No. Observations:               94472   R-squared (Within):               0.0074
# Date:                Sun, May 21 2023   R-squared (Overall):             -0.0266
# Time:                        10:57:16   Log-likelihood                  8.01e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      66.470
# Entities:                       13496   P-value                           0.0000
# Avg Obs:                       7.0000   Distribution:                 F(9,80961)
# Min Obs:                       7.0000
# Max Obs:                       7.0000   F-statistic (robust):             66.470
#                                         P-value                           0.0000
# ...

# %%
ddf['HorA_lag']=ddf['HorA'].shift(-1)

# %%
ddf.columns
# Out:
# Index(['HorA', 'Tweet_be_retweeted', 'Tweet_be_retweeted_100',
#        'Tweet_be_retweeted_1000', 'Tweet_be_retweeted_10000',
#        'Tweet_be_retweeted_50', 'Tweet_be_retweeted_500', 'Tweet_id',
#        'Tweet_retweet_count', 'User_followers_count', 'User_infuluence_score',
#        'authority', 'care', 'emoji_num', 'fairness', 'loyalty', 'purity',
#        'url_num', 'User_followers_count_log', 'authority_lag', 'care_lag',
#        'fairness_lag', 'purity_lag', 'loyalty_lag', 'HorA_lag',
#        'Tweet_id_lag'],
#       dtype='object')

# %%
#dropna
ddf2 = ddf[['HorA', 'Tweet_be_retweeted', 'Tweet_be_retweeted_50', 'Tweet_id',
       'Tweet_retweet_count', 'User_followers_count', 'User_infuluence_score',
       'authority', 'care', 'emoji_num', 'fairness', 'loyalty', 'purity',
       'url_num','HorA_lag', 'User_followers_count_log']].dropna()

# %%
#仇恨言论与道德叙事，控制发帖量，使用滞后项
reg_fe = PanelOLS.from_formula('HorA_lag ~ care+ fairness + authority+ purity + loyalty + emoji_num + url_num +User_followers_count_log+Tweet_id+EntityEffects +TimeEffects', data=ddf2)
results_fe = reg_fe.fit()
print(results_fe)
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:               HorA_lag   R-squared:                        0.0002
# Estimator:                   PanelOLS   R-squared (Between):             -0.1207
# No. Observations:               94471   R-squared (Within):               0.0002
# Date:                Sun, May 21 2023   R-squared (Overall):             -0.0532
# Time:                        10:53:09   Log-likelihood                 7.444e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      2.0907
# Entities:                       13496   P-value                           0.0268
# Avg Obs:                       6.9999   Distribution:                 F(9,80960)
# Min Obs:                       6.0000
# Max Obs:                       7.0000   F-statistic (robust):             2.0907
#                                         P-value                           0.0268
# ...

# %%
ddf2[['HorA','HorA_lag']]
# Out:
#                                    HorA  HorA_lag
# User_id             30day_cut
# 1378                0          0.007168  0.004566
#                     1          0.004566  0.000000
#                     2          0.000000  0.000000
#                     3          0.000000  0.000000
#                     4          0.000000  0.027778
# ...                                 ...       ...
# 1506717607235182592 1          0.000000  0.000000
#                     2          0.000000  0.000000
#                     3          0.000000  0.000000
#                     4          0.000000  0.000000
#                     5          0.000000  0.000000
#
# [94471 rows x 2 columns]

# %%
from stargazer.stargazer import Stargazer
from IPython.core.display import HTML

# %%
stargazer = Stargazer([results_fe_0, results_fe_1, results_fe_2])
stargazer.significance_levels([0.05, 0.01, 0.001])
stargazer.covariate_order(['care','fairness','authority','purity' ,'loyalty','emoji_num','url_num','User_followers_count_log','Tweet_id'])
HTML(stargazer.render_html())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 stargazer = Stargazer([results_fe_0, results_fe_1, results_fe_2])
#       2 stargazer.significance_levels([0.05, 0.01, 0.001])
#       3 stargazer.covariate_order(['care','fairness','authority','purity' ,'loyalty','emoji_num','url_num','User_followers_count_log','Tweet_id'])
#
# File D:\Anaconda\lib\site-packages\stargazer\stargazer.py:40, in Stargazer.__init__(self, models)
#      38 self.num_models = len(models)
#      39 self.reset_params()
# ---> 40 self.extract_data()
#
# File D:\Anaconda\lib\site-packages\stargazer\stargazer.py:104, in Stargazer.extract_data(self)
#      98 def extract_data(self):
#      99     """
#     100     Extract the values we need from the models and store
#     101     for use or modification. They should not be able to
# ...

# %%
results_fe_2
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:                   HorA   R-squared:                        0.0073
# Estimator:                   PanelOLS   R-squared (Between):             -0.0605
# No. Observations:               94472   R-squared (Within):               0.0074
# Date:                Sun, May 21 2023   R-squared (Overall):             -0.0266
# Time:                        10:57:16   Log-likelihood                  8.01e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      66.470
# Entities:                       13496   P-value                           0.0000
# Avg Obs:                       7.0000   Distribution:                 F(9,80961)
# Min Obs:                       7.0000
# Max Obs:                       7.0000   F-statistic (robust):             66.470
#                                         P-value                           0.0000
# ...
